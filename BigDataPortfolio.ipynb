# %%
import pandas as pd

# Now we need to read in the data
df = pd.read_csv(r"C:\Users\Marjan\Desktop\BigDataPortfolio\frenepublicinjection2016.csv")

#count the number of rows:

print(len(df))
df.head()
# Out:
# 27244
#               Nom_arrond Invent  no_civiq                     Rue  \
# 0  Ahuntsic-Cartierville      R      9805  Sacré-Coeur, avenue du
# 1  Ahuntsic-Cartierville      R      9825  Sacré-Coeur, avenue du
# 2  Ahuntsic-Cartierville      R      9810  Sacré-Coeur, avenue du
# 3  Ahuntsic-Cartierville      R     10432           Lille, rue de
# 4  Ahuntsic-Cartierville      R      1170     Louvain Est, rue de
#
#                       Rue_De                      Rue_A Nom_parc Sigle  \
# 0             Sauvé Est, rue           Sauriol Est, rue      NaN  FRPE
# 1             Sauvé Est, rue           Sauriol Est, rue      NaN  FRPE
# 2             Sauvé Est, rue           Sauriol Est, rue      NaN  FRPE
# 3            Fleury Est, rue            Prieur Est, rue      NaN  FRPE
# 4  Christophe-Colomb, avenue  De Bretonvilliers, avenue      NaN  FRPE
#
#    Injections              x             y  longitude   latitude
# 0        2016  292946.888016  5.046548e+06 -73.651829  45.558747
# ...
